# %% [markdown]
# # Cross-validation & Walk-forward-validation results

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from models.utils import plot_loss
from validation.utils import load_txt

# %% [markdown]
# ## 1. Cross-validation

# %%
# experiments folder (Cross-validation)
EXPERIMENTSFOLDER = '../_experiments/2019-04-24 13:40:03.647474/2019-04-24 13:40:05.546011/'

# %% [markdown]
# ### 1.1. Plot training loss

# %%
train_losses = load_txt(EXPERIMENTSFOLDER + 'train_loss.npy')

for train_loss in train_losses:
    plot_loss(train_loss)
# Out:
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)
# [plot_loss]
# title=None
# losses.shape=(2, 1474)

# %% [markdown]
# ## 2. Walk-forward validation

# %%
# experiments folder (Wald-forward validation)
EXPERIMENTSFOLDER = ''

# %% [markdown]
# ### 2.1. Plot training loss
